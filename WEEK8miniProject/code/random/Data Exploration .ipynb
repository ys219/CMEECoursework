# %%
# load modules
import pandas as pd
import  scipy as sc
import matplotlib.pylab as pl
import seaborn as sns

# %%
# import data
data = pd.read_csv("../data/CRat.csv")
print("Loaded{}columns.".format(len(data.columns.values)))
data.head()
# Out:
# Loaded68columns.
#       ID DataType           ORIGINAL_TraitID  \
# 0  39835      new  Resource Consumption Rate
# 1  39835      new  Resource Consumption Rate
# 2  39835      new  Resource Consumption Rate
# 3  39835      new  Resource Consumption Rate
# 4  39835      new  Resource Consumption Rate
#
#                             ORIGINAL_TraitDefinition  TraitValue  \
# 0  The number of resource consumed per number of ...     8.67993
# 1  The number of resource consumed per number of ...     7.66727
# 2  The number of resource consumed per number of ...     8.67993
# 3  The number of resource consumed per number of ...    18.44480
# 4  The number of resource consumed per number of ...    17.35990
#
#                           TraitUnit  N_TraitValue  \
# 0  Individual/(Individual*120 mins)      0.001206
# 1  Individual/(Individual*120 mins)      0.001065
# 2  Individual/(Individual*120 mins)      0.001206
# 3  Individual/(Individual*120 mins)      0.002562
# ...

# %%
print(data.columns.values)
print(data.TraitUnit.unique())
print(data.ResDensityUnit.unique())
print(data.ID.unique())
# Out:
# ['ID' 'DataType' 'ORIGINAL_TraitID' 'ORIGINAL_TraitDefinition' 'TraitValue'
#  'TraitUnit' 'N_TraitValue' 'ConTaxa' 'ResTaxa' 'ConTaxaStage'
#  'ResTaxaStage' 'Con_ForagingMovement' 'Con_RESDetectionDimensionality'
#  'Res_ForagingMovement' 'Res_CONDetectionDimensionality' 'CON_MASS_value'
#  'RES_MASS_value' 'ResArenaSize_SI_UNIT' 'ResDensity_SI_VALUE'
#  'ResDensityUnit' 'ResDensity' 'ResArenaSize_SI_VALUE' 'ConTemp' 'ResTemp'
#  'ResReplaceRate' 'ResReplaceUnit' 'ResReplace' 'TraitSIValue'
#  'TraitSIUnit' 'N_TraitID' 'N_TraitConversion' 'N_CONVERTED' 'N_TraitUnit'
#  'Original_ErrorValue' 'Original_ErrorValueUnit' 'Replicates' 'ConTaxon'
#  'ConStage' 'ConCommon' 'Con_MovementDimensionality' 'Con_Thermy'
#  'Res_MovementDimensionality' 'ResTaxon' 'ResStage' 'ResCommon'
#  'Res_Thermy' 'Habitat' 'LabField' 'ObservationtimeSI'
#  'ObservationtimeSIUnits' 'ConStarvationTimeSI' 'ConStarvationTimeSIUnits'
#  'ConArenaSiz_VALUE' 'ConArenaSize_UNIT' 'ConDensity' 'ConDensityUnit'
# ...

# %%
data_sub_39982 = data[data["ID"]== 39982]
data_sub_39982.head
# Out:
# <bound method NDFrame.head of          ID DataType           ORIGINAL_TraitID  \
# 1552  39982      new  Resource Consumption Rate
# 1553  39982      new  Resource Consumption Rate
# 1554  39982      new  Resource Consumption Rate
# 1555  39982      new  Resource Consumption Rate
# 1556  39982      new  Resource Consumption Rate
# 1557  39982      new  Resource Consumption Rate
# 1558  39982      new  Resource Consumption Rate
# 1559  39982      new  Resource Consumption Rate
# 1560  39982      new  Resource Consumption Rate
#
#                                ORIGINAL_TraitDefinition  TraitValue  \
# 1552  The number of resource consumed per number of ...     15.3020
# 1553  The number of resource consumed per number of ...     17.6631
# 1554  The number of resource consumed per number of ...     50.1713
# 1555  The number of resource consumed per number of ...     47.9275
# 1556  The number of resource consumed per number of ...     78.3936
# ...

# %%
sns.lmplot("ResDensity", "N_TraitValue", data = data_sub_39982, fit_reg  = False)
